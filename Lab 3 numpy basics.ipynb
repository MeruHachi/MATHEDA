# %% [markdown]
# # Numpy <hr style="border:2.5px dotted rgba(61, 19, 77, 1)"></hr>

# %% [markdown]
# <b>Mel Justin M. Villa</b>
# <br>Computer Engineering Student at <a href="https://www.tup.edu.ph" target="_blank">TUPV</a>
# <br>Contact me at: <a href="mailto:melv.online05@gmail.com">melv.online05@gmail.com</a><br>

# %%
#import and packages
import numpy as np

# %%
my_array = [1,2,3]

# %%
type(my_array)
# Out:
# list

# %%
my_array = np.array([1,2,3])

# %%
np.shape(my_array)
# Out:
# (3,)

# %% [markdown]
# <b><h1>2D array</b></h1>

# %%
my_array = np.array([
    [1,2,3],
    [4,5,6],
])

# %%
np.shape(my_array)
# Out:
# (2, 3)

# %%
trans_array=my_array.T

# %%
np.shape(trans_array)
# Out:
# (3, 2)

# %%
np.sum(trans_array,axis=0)
# Out:
# array([ 6, 15])

# %%
np.sum(trans_array,axis=1)
# Out:
# array([5, 7, 9])

# %% [markdown]
# <b><h1>Measure of Central Tendency</b></h1>

# %%
resistance = np.array([
    [10.6,9.1,9.3,9.8,10.5,10.4,9.5,11,10.4,3,9.8],
    [10.1,11,9.1,20,9.2,10.8,9.9,9.2,9.1,9.1,np.nan]
])
resistance
# Out:
# array([[10.6,  9.1,  9.3,  9.8, 10.5, 10.4,  9.5, 11. , 10.4,  3. ,  9.8],
#        [10.1, 11. ,  9.1, 20. ,  9.2, 10.8,  9.9,  9.2,  9.1,  9.1,  nan]])

# %%
#Mean
np.nanmean(resistance, axis=1)
# Out:
# array([ 9.4 , 10.75])

# %%
row1 = resistance[0]
row2 = resistance[1]

# %%
row1
# Out:
# array([10.6,  9.1,  9.3,  9.8, 10.5, 10.4,  9.5, 11. , 10.4,  3. ,  9.8])

# %%
row2
# Out:
# array([10.1, 11. ,  9.1, 20. ,  9.2, 10.8,  9.9,  9.2,  9.1,  9.1,  nan])

# %%
median_row1 = np.nanmedian(resistance[0])
median_row2 = np.nanmedian(resistance[1])
median_row1
# Out:
# np.float64(9.8)

# %%
median_row2
# Out:
# np.float64(9.55)

# %%
values, counts = np.unique(row1, return_counts=True)

mxcount = np.max(counts)
modes_row1 = values[counts == max_count]
modes_row1
# Out:
# array([ 9.8, 10.4])

# %%
row2 = row2[~np.isnan(row2)]   # remove NaN

values2, counts2 = np.unique(row2, return_counts=True)
mode_row2 = values2[np.argmax(counts2)]
mode_row2
# Out:
# np.float64(9.1)

# %% [markdown]
# <b><h1>Variation</b></h1>

# %%
std_row1 = np.std(row1)
std_row1
# Out:
# np.float64(2.101947149236112)

# %%
std_row2 = np.std(row2)
std_row2
# Out:
# np.float64(3.1582431825304393)

# %%
var_row1 = np.var(row1)
var_row1
# Out:
# np.float64(4.418181818181818)

# %%
var_row2 = np.var(row2)
var_row2
# Out:
# np.float64(9.974499999999999)
