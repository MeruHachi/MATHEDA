# %% [markdown]
# # Lists and Tuples <hr style="border:2.5px dotted rgba(61, 19, 77, 1)"></hr>

# %% [markdown]
# <b>Mel Justin M. Villa</b>
# <br>Computer Engineering Student at <a href="https://www.tup.edu.ph" target="_blank">TUPV</a>
# <br>Contact me at: <a href="mailto:melv.online05@gmail.com">melv.online05@gmail.com</a><br>

# %% [markdown]
# <b><h1>Creating a List</b></h1>

# %%
numbers=[1,2,3,4,5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
mixed_list = [1, 'apple', 3.14, True]
mixed_list
# Out:
# [1, 'apple', 3.14, True]

# %% [markdown]
# <b><h1>Indexing</b></h1>

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %% [markdown]
# <b><h1>Modifying</b></h1>

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits[0]='orange'
fruits
# Out:
# ['orange', 'banana', 'grape']

# %% [markdown]
# <b><h1>Removing Elements</b></h1>

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
fruits.remove('banana')

# %%
fruits
# Out:
# ['apple', 'grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %% [markdown]
# <b><h1>Sort() and Sorted()</b></h1>

# %%
numbers = [3, 1, 5, 4, 2]
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
sorted(numbers,reverse=True)
# Out:
# [5, 4, 3, 2, 1]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# <b><h1>Slicing</b></h1>

# %%
chars = ('a', 'b', 'c', 'x', 'y')
chars
# Out:
# ('a', 'b', 'c', 'x', 'y')

# %%
len(chars)
# Out:
# 5

# %%
chars[1:4]
# Out:
# ('b', 'c', 'x')

# %%
sub = chars[1:4]
sub
# Out:
# ('b', 'c', 'x')

# %%
chars[0:5:2]
# Out:
# ('a', 'c', 'y')

# %% [markdown]
# <b><h1>Tuples</b></h1>

# %%
my_typle = (1, 2, 3, 4, 5)

# %%
type(my_typle)
# Out:
# tuple

# %%
len(my_typle)
# Out:
# 5

# %%
my_typle[2]
# Out:
# 3

# %%
my_typle[1:4]
# Out:
# (2, 3, 4)

# %%
my_typle = (2,2,3,4,5)
my_typle
# Out:
# (2, 2, 3, 4, 5)

# %%
mixed_mytuple = (10,'hello',2.5,True)
mixed_mytuple
# Out:
# (10, 'hello', 2.5, True)
