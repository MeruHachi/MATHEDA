# %% [markdown]
# # Standard Normal Distribution <hr style="border:2.5px dotted rgba(61, 19, 77, 1)"></hr>

# %% [markdown]
# <b>Mel Justin M. Villa</b>
# <br>Computer Engineering Student at <a href="https://www.tup.edu.ph" target="_blank">TUPV</a>
# <br>Contact me at: <a href="mailto:melv.online05@gmail.com">melv.online05@gmail.com</a><br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# <b><h1>Z-Score</b></h1>

# %%
df = pd.DataFrame([1,2,2,3,3,3,4,4,5], columns=['Dataset'])
df
# Out:
#    Dataset
# 0        1
# 1        2
# 2        2
# 3        3
# 4        3
# 5        3
# 6        4
# 7        4
# 8        5

# %%
df.describe()
# Out:
#         Dataset
# count  9.000000
# mean   3.000000
# std    1.224745
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
df['Z-score'] = stats.zscore(df['Dataset'],ddof=1)
df
# Out:
#    Dataset   Z-score
# 0        1 -1.632993
# 1        2 -0.816497
# 2        2 -0.816497
# 3        3  0.000000
# 4        3  0.000000
# 5        3  0.000000
# 6        4  0.816497
# 7        4  0.816497
# 8        5  1.632993

# %%
cdf = pd.read_csv(r"dataset\current-test.csv",delimiter =',', index_col='Sample')
cdf
# Out:
#         Current
# Sample
# 1          12.0
# 2          15.0
# 3           8.3
# 4           9.7
# 5          12.0
# 6          13.9
# 7          14.1
# 8           9.2
# 9          12.4
# 10         13.7
# 11         10.6
# 12         21.5
# 13         12.0
# 14          9.3
# 15         11.2
# 16          3.3
# 17         12.4
# 18         12.3
# 19         13.8
# 20         10.5
# 21         10.4
# 22         15.0
# 23         12.7
# 24         14.4
# 25         11.0
# 26          9.1
# 27         10.2
# 28         12.4
# 29          7.0
# 30         14.8

# %%
cdf['Current'][3]
# Out:
# np.float64(8.3)

# %%
s1_mean = cdf['Current'][4:6].mean()
s1_mean
# Out:
# np.float64(12.95)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 1 to 30
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Current  30 non-null     float64
# dtypes: float64(1)
# memory usage: 1.5 KB

# %%
cdf.describe()
# Out:
#          Current
# count  30.000000
# mean   11.806667
# std     3.166629
# min     3.300000
# 25%    10.250000
# 50%    12.000000
# 75%    13.775000
# max    21.500000

# %%
cdf['Z-score'] = stats.zscore(cdf['Current'],ddof=1)
cdf
# Out:
#         Current   Z-score
# Sample
# 1          12.0  0.061053
# 2          15.0  1.008433
# 3           8.3 -1.107382
# 4           9.7 -0.665271
# 5          12.0  0.061053
# 6          13.9  0.661060
# 7          14.1  0.724219
# 8           9.2 -0.823168
# 9          12.4  0.187371
# 10         13.7  0.597902
# 11         10.6 -0.381057
# 12         21.5  3.061089
# 13         12.0  0.061053
# 14          9.3 -0.791588
# 15         11.2 -0.191581
# 16          3.3 -2.686348
# 17         12.4  0.187371
# 18         12.3  0.155791
# 19         13.8  0.629481
# 20         10.5 -0.412636
# 21         10.4 -0.444216
# 22         15.0  1.008433
# 23         12.7  0.282109
# 24         14.4  0.818957
# 25         11.0 -0.254740
# 26          9.1 -0.854747
# 27         10.2 -0.507374
# 28         12.4  0.187371
# 29          7.0 -1.517913
# 30         14.8  0.945274

# %%
cdf['Z-score'].describe()
# Out:
# count    3.000000e+01
# mean     7.401487e-18
# std      1.000000e+00
# min     -2.686348e+00
# 25%     -4.915848e-01
# 50%      6.105335e-02
# 75%      6.215863e-01
# max      3.061089e+00
# Name: Z-score, dtype: float64

# %% [markdown]
# <b><h1>Histogram</b></h1>

# %%
plt.hist(cdf['Current'], bins = 5,
         alpha = 0.8,
         color = '#fce300',
         edgecolor = '#000000')
plt.show()

# %%
plt.hist(cdf['Current'], bins = 5,
         alpha = 0.8,
         color = '#fce300',
         edgecolor = '#000000')

plt.title('Histogram of Current Values',
          font = 'Courier New', fontsize = 12)

plt.xlabel('Current(mA)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <b><h1>Normal Distribution</b></h1>

# %%
cmean = cdf['Current'].mean()
cstd = cdf['Current'].std(ddof=1)

x_min = cdf['Current'].min()
x_max = cdf['Current'].max()

x = np.linspace(x_min,x_max,100)
p = stats.norm.pdf(x, cmean, cstd)

plt.plot(x, p,
         color = "#FF0000",
         linewidth = 2)


plt.title('Normal Distribution of Current Values',
          font = 'Courier New', fontsize = 12)

plt.xlabel('Current(mA)')
plt.ylabel('Probability Density')
plt.show()

# %%
plt.hist(cdf['Current'], bins = 5,
         density=True,
         alpha = 0.8,
         color = '#fce300',
         edgecolor = '#000000')

plt.title('Normal Distribution of Current Values',
          font = 'Courier New', fontsize = 12)
plt.xlabel('Current(mA)')
plt.ylabel('Probability Density')

plt.plot(x, p,
         color = "#FF0000",
         linewidth = 2)

plt.show()

# %% [markdown]
# <b><h1>Standard Normal Distribution N(0,1)
# </b></h1>

# %%
zmean = cdf['Z-score'].mean()
zstd = cdf['Z-score'].std(ddof=1)

z_min = cdf['Z-score'].min()
z_max = cdf['Z-score'].max()

xz = np.linspace(z_min,z_max,100)
pz = stats.norm.pdf(xz, zmean, zstd)

plt.plot(xz, pz,
         color = "#FF0000",
         linewidth = 2)


plt.title('Normal Distribution of Current Values N(0,1)',
          font = 'Courier New', fontsize = 12)

plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.show()
