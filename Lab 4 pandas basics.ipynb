# %% [markdown]
# # Panda Basics <hr style="border:2.5px dotted rgba(61, 19, 77, 1)"></hr>

# %% [markdown]
# <b>Mel Justin M. Villa</b>
# <br>Computer Engineering Student at <a href="https://www.tup.edu.ph" target="_blank">TUPV</a>
# <br>Contact me at: <a href="mailto:melv.online05@gmail.com">melv.online05@gmail.com</a><br>

# %%
#%pip install matplotlib --upgrade
# Out:
# Requirement already satisfied: matplotlib in c:\users\melju\appdata\roaming\python\python314\site-packages (3.10.8)
# Requirement already satisfied: numpy in c:\users\melju\appdata\roaming\python\python314\site-packages (2.4.1)
# Requirement already satisfied: pandas in c:\users\melju\appdata\roaming\python\python314\site-packages (2.3.3)
# Requirement already satisfied: stats in c:\users\melju\appdata\roaming\python\python314\site-packages (0.1.2a0)
# Requirement already satisfied: scipy in c:\users\melju\appdata\roaming\python\python314\site-packages (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 1.10.0 Requires-Python >=3.8,<3.12; 1.10.0rc1 Requires-Python >=3.8,<3.12; 1.10.0rc2 Requires-Python >=3.8,<3.12; 1.10.1 Requires-Python >=3.8,<3.12; 1.11.0 Requires-Python >=3.9,<3.13; 1.11.0rc1 Requires-Python >=3.9,<3.13; 1.11.0rc2 Requires-Python >=3.9,<3.13; 1.11.1 Requires-Python >=3.9,<3.13; 1.11.2 Requires-Python >=3.9,<3.13; 1.11.3 Requires-Python >=3.9,<3.13; 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11; 1.26.0 Requires-Python >=3.9,<3.13; 1.26.1 Requires-Python >=3.9,<3.13; 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10; 1.7.2 Requires-Python >=3.7,<3.11; 1.7.3 Requires-Python >=3.7,<3.11; 1.8.0 Requires-Python >=3.8,<3.11; 1.8.0rc1 Requires-Python >=3.8,<3.11; 1.8.0rc2 Requires-Python >=3.8,<3.11; 1.8.0rc3 Requires-Python >=3.8,<3.11; 1.8.0rc4 Requires-Python >=3.8,<3.11; 1.8.1 Requires-Python >=3.8,<3.11; 1.9.0 Requires-Python >=3.8,<3.12; 1.9.0rc1 Requires-Python >=3.8,<3.12; 1.9.0rc2 Requires-Python >=3.8,<3.12; 1.9.0rc3 Requires-Python >=3.8,<3.12; 1.9.1 Requires-Python >=3.8,<3.12
# ERROR: Could not find a version that satisfies the requirement statsmodel (from versions: none)
# ERROR: No matching distribution found for statsmodel

# %%
#imports and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <b><h1>DataFrame</b></h1>

# %%
#creating dictionary
data = {
    "Name":['Henry','Owen','Ada'],
    "Age":[22,35,58],
    "Sex":['M','M','F']
}

# %%
#creating dataframe from dictionary
df=pd.DataFrame(data)
df
# Out:
#     Name  Age Sex
# 0  Henry   22   M
# 1   Owen   35   M
# 2    Ada   58   F

# %% [markdown]
# <b><h1>Series</b></h1>

# %%
# selecting 'Name' column
df['Name']
# Out:
# 0    Henry
# 1     Owen
# 2      Ada
# Name: Name, dtype: object

# %%
# selecting 'Age' column
df['Age']
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
# selecting 'Sex' column
df['Sex']
# Out:
# 0    M
# 1    M
# 2    F
# Name: Sex, dtype: object

# %% [markdown]
# <b><h1>Descriptive Statistics</b></h1>

# %%
# Jaguar vs Panther
resistance = np.array([
    [10.6,9.1,9.3,9.8,10.5,10.4,9.5,11,10.4,3,9.8],
    [10.1,11,9.1,20,9.2,10.8,9.9,9.2,9.1,9.1,np.nan]
]).T
resistance
# Out:
# array([[10.6, 10.1],
#        [ 9.1, 11. ],
#        [ 9.3,  9.1],
#        [ 9.8, 20. ],
#        [10.5,  9.2],
#        [10.4, 10.8],
#        [ 9.5,  9.9],
#        [11. ,  9.2],
#        [10.4,  9.1],
#        [ 3. ,  9.1],
#        [ 9.8,  nan]])

# %%
# Creating DataFrame from numpy array
df=pd.DataFrame(resistance,columns=['Jaguar','Panther'])
df
# Out:
#     Jaguar  Panther
# 0     10.6     10.1
# 1      9.1     11.0
# 2      9.3      9.1
# 3      9.8     20.0
# 4     10.5      9.2
# 5     10.4     10.8
# 6      9.5      9.9
# 7     11.0      9.2
# 8     10.4      9.1
# 9      3.0      9.1
# 10     9.8      NaN

# %%
# Summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   11 non-null     float64
#  1   Panther  10 non-null     float64
# dtypes: float64(2)
# memory usage: 308.0 bytes

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Summary of statistics
df.describe()
# Out:
#           Jaguar    Panther
# count  11.000000  10.000000
# mean    9.400000  10.750000
# std     2.204541   3.329081
# min     3.000000   9.100000
# 25%     9.400000   9.125000
# 50%     9.800000   9.550000
# 75%    10.450000  10.625000
# max    11.000000  20.000000

# %%
# Median
jag_median = df['Jaguar'].median()
pan_median = df['Panther'].median()

print(f'Jaguar Median ={jag_median:.2f} ohms')
print(f'Panther Median ={pan_median:.2f} ohms')
# Out:
# Jaguar Median =9.80 ohms
# Panther Median =9.55 ohms

# %%
# Mode
jag_mode = df['Jaguar'].mode()
pan_mode = df['Panther'].mode()

# %%
jag_mode
# Out:
# 0     9.8
# 1    10.4
# Name: Jaguar, dtype: float64

# %%
jag_mode.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2 entries, 0 to 1
# Series name: Jaguar
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      float64
# dtypes: float64(1)
# memory usage: 148.0 bytes

# %%
type(jag_mode)
# Out:
# pandas.core.series.Series

# %%
print('Jaguar Mode:')

for i in jag_mode:
    print(i)
# Out:
# Jaguar Mode:
# 9.8
# 10.4

# %%
print('Panther Mode:')

for i in pan_mode:
    print(i)
# Out:
# Panther Mode:
# 9.1

# %%
# Jaguar IQR
Q1 =df['Jaguar'].quantile(0.25)
Q3 =df['Jaguar'].quantile(0.75)


print(f'Jaguar IQR ={Q3-Q1:.2f}.ohms')
# Out:
# Jaguar IQR =1.05.ohms

# %%
# Panther IQR
Q1 =df['Panther'].quantile(0.25)
Q3 =df['Panther'].quantile(0.75)


print(f'Panther IQR ={Q3-Q1:.2f}.ohms')
# Out:
# Panther IQR =1.50.ohms

# %% [markdown]
# <b><h1>Descriptive Statistics</b></h1>

# %%
jag_mean = df['Jaguar'].mean()
pan_mean = df['Panther'].mean()

plt.figure(figsize=(7,4))
bars = plt.bar(['Jaguar','Panther'],[jag_mean,pan_mean],
                color='#126782')
plt.title('Average Resistance by Machine')
plt.ylabel('Resistance(ohms)')

#bar labels
plt.bar_label(bars,padding=3)
plt.margins(y=0.1)
plt.show()
